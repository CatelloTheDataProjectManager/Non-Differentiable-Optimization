# %% [markdown]
# # Differentiable Optimization
#
# - **Linear Regression**: Suppose we have a dataset of housing prices and corresponding features such as square footage, number of bedrooms, and location.  We can use linear regression to model the relationship between these features and the housing prices.
# - **Logistic Regression**: Suppose we have a dataset of customer churn data, where each data point represents a customer and indicates whether or not they churned. We can use logistic regression to model the probability of churning based on various features such as age, income, and usage patterns.

# %% [markdown]
# ## Optimization of continuous function
#
# We study critical points in optimization because they represent locations where the function’s slope is zero (i.e., the gradient vanishes). These points are candidates for local minima, maxima, or saddle points, where significant changes in the function’s behavior occur, making them essential for finding optimal solutions.
#
# f(x) = (x-1)²(x+2)
#
# 1. Is this optimization problem continuous or discrete? Does it have any constraints? Is it convex or non-convex? Is it deterministic or stochastic?
# 2. What is the search space of this function?
# 3. Plot the graph of this function.
# 4. Identify graphically the local and global minima of the function.
# 5. Calculate the derivative of the function.
# 6. Using the derivative, find the critical points of the function.
# 7. Calculate the second derivative of the function.

# %% [markdown]
# **Is this optimization problem continuous or discrete? Does it have any constraints? Is it convex or non-convex? Is it deterministic or stochastic?**
#
# - Continuous: The variable x can take any real value, so the problem is continuous.
# - Constraints: There are no explicit constraints mentioned in the problem statement, so the problem is considered unconstrained.
# - Convexity: The function f(x) = (x-1)²(x+2) is not a quadratic function, so it's not immediately clear if it's convex or not. However, since the function is a product of two quadratic functions, it's not necessarily convex. To determine convexity, further analysis would be needed.
# - Deterministic or Stochastic: The problem is deterministic because there is no random variable or uncertainty involved.

# %% [markdown]
# **What is the search space of this function?**
#
# The search space of the function f(x) = (x-1)²(x+2) is the set of all real numbers, denoted as R. Since there are no constraints mentioned in the problem statement, the search space is not limited to a specific range or set of values.

# %% [markdown]
# **Plot the graph of this function.**
#
# This code will generate a plot of the function f(x) = (x-1)²(x+2) over the range of x values from -5 to 5.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function
def f(x):
    return (x-1)**2 * (x+2)

# Generate x values
x = np.linspace(-5, 5, 400)

# Generate y values
y = f(x)

# Create the plot
plt.figure(figsize=(8, 6))
plt.plot(x, y, label='f(x) = (x-1)^2 * (x+2)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Graph of f(x) = (x-1)^2 * (x+2)')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# **Identify graphically the local and global minima of the function.**
#
# Based on the graph of the function f(x) = (x-1)²(x+2), we can identify the local and global minima graphically.
#
# From the graph, we can see that the function has a minimum at x = -1. Since this minimum is the lowest point on the graph, it is both the local and global minimum of the function.
#
# Therefore, the global minimum of the function f(x) = (x-1)²(x+2) is at x = -1, and the minimum value is f(-1) = 0.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import minimize

# Define the function
def f(x):
    return (x-1)**2 * (x+2)

# Generate x values
x = np.linspace(-5, 5, 400)

# Generate y values
y = f(x)

# Find the global minimum using scipy.optimize.minimize
result = minimize(f, x0=0)

# Create the plot
plt.figure(figsize=(8, 6))
plt.plot(x, y, label='f(x) = (x-1)^2 * (x+2)')
plt.plot(result.x, result.fun, 'ro', label='Local minimum')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Graph of f(x) = (x-1)^2 * (x+2)')
plt.grid(True)
plt.legend()
plt.show()

# Print the global minimum
print(f"The global minimum of the function is at x = {result.x[0]} and f(x) = {result.fun}")
# Out:
# The global minimum of the function is at x = 1.0000000037253827 and f(x) = 4.1635428143551895e-17

# %% [markdown]
# In this case, the function f(x) = (x-1)^2 * (x+2) does not have a **global minimum** because it can take on arbitrarily small values as x approaches negative infinity. Therefore, there is no single point that is the lowest value that the function can take over its entire domain.

# %% [markdown]
# **Calculate the derivative of the function**
#
# In order to find the minimum of a function, we can calculate its derivative and set it equal to zero to find the critical points. At these critical points, the derivative is zero, which means that the slope of the function is zero. If the function is continuous and the derivative changes sign at a critical point, then that critical point is a local minimum.
#
# **The first derivative**
#
# The first derivative is commonly referred to as the "first derivative" in English. It measures the rate of change of a function with respect to its independent variable. In other words, it represents the slope of the tangent line to the curve of the function at a given point.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function
def f(x):
    return (x-1)**2 * (x+2)

# Define the derivative of the function
def f_prime(x):
    return 3*x**2 - 2*x - 3

# Generate x values
x = np.linspace(-5, 5, 400)

# Generate y values for the function and its derivative
y = f(x)
y_prime = f_prime(x)

# Create the plot
plt.figure(figsize=(8, 6))
plt.plot(x, y, label='f(x) = (x-1)^2 * (x+2)')
plt.plot(x, y_prime, label="f'(x) = 3x^2 - 2x - 3")
plt.xlabel('x')
plt.ylabel('y')
plt.title('Graph of f(x) and its derivative')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# **Using the derivative, find the critical points of the function.**
#
# In mathematics, critical points of a function are the points where the derivative is equal to zero or undefined. These points are significant because they can indicate local extrema (minima or maxima) or points of inflection of the function. In the context of the function f(x) = (x-1)^2 * (x+2), the critical points are the solutions to the equation f'(x) = 0.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import root

# Define the function
def f(x):
    return (x-1)**2 * (x+2)

# Define the derivative of the function
def f_prime(x):
    return 3*x**2 - 2*x - 3

# Generate x values
x = np.linspace(-5, 5, 400)

# Generate y values for the function
y = f(x)

# Find the critical points using scipy.optimize.root
critical_points = root(f_prime, [-1, 3])

# Create the plot
plt.figure(figsize=(8, 6))
plt.plot(x, y, label='f(x) = (x-1)^2 * (x+2)')
plt.plot(critical_points.x, f(critical_points.x), 'ro', label='Critical points')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Graph of f(x) = (x-1)^2 * (x+2)')
plt.grid(True)
plt.legend()
plt.show()

critical_points.x
# Out:
# array([-0.72075922,  1.38742589])

# %% [markdown]
# **Calculate the second derivative of the function.**
#
# This will plot the function f(x) and its second derivative f''(x) on the same graph. The second derivative can be used to determine the concavity of the function, which can help us to determine the nature of the critical points.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function
def f(x):
    return (x-1)**2 * (x+2)

# Define the derivative of the function
def f_prime(x):
    return 3*x**2 - 2*x - 3

# Define the second derivative of the function
def f_double_prime(x):
    return 6*x

# Generate x values
x = np.linspace(-5, 5, 400)

# Generate y values for the function and its second derivative
y = f(x)
y_double_prime = f_double_prime(x)

# Create the plot
plt.figure(figsize=(8, 6))
plt.plot(x, y, label='f(x) = (x-1)^2 * (x+2)')
plt.plot(x, y_double_prime, label="f''(x) = 6x")
plt.xlabel('x')
plt.ylabel('y')
plt.title('Graph of f(x) and its second derivative')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# We can use the sign of the second derivative to determine the nature of the critical points of the function. If the second derivative is positive at a critical point, then that critical point is a local minimum. If the second derivative is negative at a critical point, then that critical point is a local maximum. If the second derivative is zero at a critical point, then that critical point is a point of inflection.

# %% [markdown]
# ## The cost of producing x units
#
# Profit(x)=Revenue(x)−Cost(x)
#
# A company produces and sells a single type of product. The cost of producing x units is given by the function:
#
# C(x) = 1000 + 20x + 0.01x^2
#
# The unit selling price is 50 €. We are trying to optimize profit.
#
# 1. Is this an optimization problem that is continuous or discrete? With or without constraints? Convex or non-convex? Deterministic or stochastic? Justify your answers.
# 2. Express the company's profit as a function of the number of units produced. Profit = Revenue - Cost
# 3. What is the search space for this optimization problem? Justify your answer.
# 4. Determine the number of units to produce to maximize profit.
# 5. How does the maximum profit change if the fixed production cost (1000 €) increases by 10%?ses by 10%?

# %% [markdown]
# **Express the company's profit as a function of the number of units produced.**

# %% [raw]
# Profit(x)=Revenue(x)−Cost(x)
# Revenue(x)=50x
# Cost(x)=C(x)=1000+20x+0.01x^2
# P(x)=−0.01x^2+30x−1000

# %% [markdown]
# **Is this an optimization problem that is continuous or discrete? With or without constraints? Convex or non-convex? Deterministic or stochastic? Justify your answers.**
#
# This is an optimization problem that is continuous and without constraints.
#
# The function C(x) is a **continuous function** of the variable x, which can take any real value. This means that there are an infinite number of possible values for x that could potentially be optimal, and it is possible to find a value of x that is not an integer. Therefore, the problem is continuous.
#
# There are no **constraints** mentioned in the problem statement, so the problem is unconstrained. This means that there are no restrictions on the values of x that could be considered as potential solutions to the problem.
#
# The function C(x) is a quadratic function, which is a type of polynomial function. Quadratic functions are always **convex**, meaning that the minimum value of the function occurs at the vertex of the parabola, which can be found by taking the derivative of the function and setting it equal to zero. Since the function is convex, there is only one optimal solution.
#
# The problem is **deterministic**, meaning that all the input values (the cost of production and the selling price) are known with certainty. There is no uncertainty or randomness involved in the problem.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Profit function
def profit(x):
    return -0.01*x**2 + 30*x - 1000

# Generate values for x (number of units produced)
x_values = np.linspace(0, 5000, 500)

# Calculate corresponding profit values
profit_values = profit(x_values)

# Plot the profit function
plt.figure(figsize=(8, 6))
plt.plot(x_values, profit_values, label='Profit P(x)', color='blue')
plt.title("Profit Function P(x) = -0.01x^2 + 30x - 1000")
plt.xlabel("Number of Units Produced (x)")
plt.ylabel("Profit (€)")
plt.grid(True)
plt.axhline(0, color='black',linewidth=1)
plt.axvline(0, color='black',linewidth=1)
plt.legend()
plt.show()

# %% [markdown]
# **What is the search space for this optimization problem?**

# %% [markdown]
# Thus, the search space for this optimization problem is the continuous interval
# [0,∞), representing all non-negative values for x. This includes all possible production levels starting from zero and extending indefinitely unless real-world constraints are added to restrict the maximum number of units that can be produced.

# %% [markdown]
# **Determine the number of units to produce to maximize profit**
#
# The number of units to produce in order to maximize profit is x=1500. This is the critical point where the derivative of the profit function equals zero, indicating the maximum profit level.

# %%
from sympy import symbols, diff, solve

# Define the symbol and the profit function
x = symbols('x')
profit_expr = -0.01*x**2 + 30*x - 1000

# Calculate the derivative of the profit function
profit_derivative = diff(profit_expr, x)

# Solve for the value of x where the derivative is 0
critical_points = solve(profit_derivative, x)

# Convert to numerical value
critical_points = [float(point) for point in critical_points]
critical_points
# Out:
# [1500.0]

# %% [markdown]
# **Second derivative**

# %%
from sympy import symbols, diff, solve

# Define the symbol and the profit function
x = symbols('x')
profit_expr = -0.01*x**2 + 30*x - 1000

# Calculate the first derivative of the profit function
profit_derivative = diff(profit_expr, x)

# Solve for the value of x where the first derivative is 0 (critical points)
critical_points = solve(profit_derivative, x)

# Calculate the second derivative of the profit function
profit_second_derivative = diff(profit_derivative, x)

# Evaluate the second derivative at the critical points
second_derivative_values = [profit_second_derivative.evalf(subs={x: cp}) for cp in critical_points]

critical_points, second_derivative_values
# Out:
# ([1500.00000000000], [-0.0200000000000000])

# %% [markdown]
# Here’s a rephrased version in English without the original formatting:
#
# Evaluate the second derivative by substituting the critical points into it.
#
# - If the second derivative is greater than zero, the function is concave up, and the critical point is a local minimum.
# - If the second derivative is less than zero, the function is concave down, and the critical point is a local maximum.
# - If the second derivative equals zero, the test is inconclusive.

# %%
# Adding the critical point (maximum profit) to the plot

# Critical point (x = 1500)
critical_x = 1500
critical_profit = profit(critical_x)

# Plot the profit function
plt.figure(figsize=(8, 6))
plt.plot(x_values, profit_values, label='Profit P(x)', color='blue')
plt.scatter(critical_x, critical_profit, color='red', zorder=5, label=f'Max Profit at x = {critical_x}')
plt.title("Profit Function P(x) = -0.01x^2 + 30x - 1000")
plt.xlabel("Number of Units Produced (x)")
plt.ylabel("Profit (€)")
plt.grid(True)
plt.axhline(0, color='black',linewidth=1)
plt.axvline(critical_x, color='red', linestyle='--', linewidth=1)  # Add a vertical line at the critical point
plt.legend()
plt.show()

# %% [markdown]
# **How does the maximum profit change if the fixed production cost (1000 €) increases by 10%?**
#
# The original maximum profit at 1500 units was €21,500. After increasing the fixed production cost by 10%, the new maximum profit is €21,400. Therefore, the maximum profit decreases by €100 due to the increase in the fixed cost.

# %%
# New fixed cost with a 10% increase
new_fixed_cost = 1000 * 1.10

# New profit function with increased fixed cost
def new_profit(x):
    return -0.01*x**2 + 30*x - new_fixed_cost

# Calculate the new maximum profit by substituting x = 1500 (the number of units that maximizes profit)
new_max_profit = new_profit(1500)

# Calculate the original maximum profit for comparison
original_max_profit = profit(1500)

original_max_profit, new_max_profit
# Out:
# (21500.0, 21400.0)

# %% [markdown]
# ##### **Gradient**
#
# When dealing with multiple variables and parameters in relation to critical points, the gradient is the vector that indicates the direction of the steepest ascent.
#
# Calculating the gradient helps you understand the behavior of a function in multiple dimensions by providing directional information about how the function increases. It's a fundamental concept in calculus, optimization, and many fields of science and engineering.

# %% [markdown]
# **3D Function**
#
# https://www.geogebra.org/3d
#
# A 3D function is a mathematical representation that relates three variables. It consists of an output variable and two input variables. This type of function can be visualized in three-dimensional space. In this visualization, the input variables correspond to the horizontal plane, while the output variable represents the vertical axis.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the function
def f(x, y):
    return x**2 + y**2

# Create a grid of (x, y) points
x_vals = np.linspace(-6, 6, 100)
y_vals = np.linspace(-6, 6, 100)
X, Y = np.meshgrid(x_vals, y_vals)
Z = f(X, Y)  # Calculate the function values

# Create a 3D surface plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X, Y, Z, cmap='viridis', edgecolor='none')

# Add color bar and labels
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)
ax.set_title('$f(x, y) = x^2 + y^2$', fontsize=16)
ax.set_xlabel('X-axis', fontsize=12)
ax.set_ylabel('Y-axis', fontsize=12)
ax.set_zlabel('Z-axis', fontsize=12)

plt.show()

# %% [markdown]
# When you calculate the gradient at a point, you're determining how the function changes around that point. The gradient vector points in the direction where the function's value increases most rapidly.

# %%
import sympy as sp

# Définir les variables
x, y = sp.symbols('x y')

# Définir la fonction
f = x**2 + y**2

# Calculer le gradient
gradient_f = [sp.diff(f, var) for var in (x, y)]

# Afficher le résultat
print("Le gradient de f est :", gradient_f)
# Out:
# Le gradient de f est : [2*x, 2*y]

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# Define the variables
x, y = sp.symbols('x y')

# Define the function
f = x**2 + y**2

# Calculate the gradient
gradient_f = [sp.diff(f, var) for var in (x, y)]

# Convert the gradient to a numerical function
gradient_func = sp.lambdify((x, y), gradient_f)

# Gradient Descent Parameters
learning_rate = 0.1  # Step size
max_iterations = 100  # Maximum number of iterations
tolerance = 1e-6  # Tolerance for stopping criterion

# Initial point
point = np.array([5.0, 5.0])  # Starting point (x, y)

# To store points for visualization
points = [point.copy()]

# Gradient Descent Loop
for iteration in range(max_iterations):
    grad = np.array(gradient_func(*point), dtype=float)  # Calculate gradient at current point
    new_point = point - learning_rate * grad  # Update point

    # Check for convergence (if the change is small)
    if np.linalg.norm(new_point - point) < tolerance:
        print(f"Converged in {iteration} iterations.")
        break
    
    point = new_point  # Move to the new point
    points.append(point.copy())  # Store the new point for visualization

print(f"Minimum found at: {point}")
print(f"Minimum value of f at this point: {f.subs({x: point[0], y: point[1]})}")

# Visualization
# Create a grid of (x, y) points
x_vals = np.linspace(-6, 6, 100)
y_vals = np.linspace(-6, 6, 100)
X, Y = np.meshgrid(x_vals, y_vals)
Z = X**2 + Y**2  # Calculate the function values

# Create the contour plot
plt.figure(figsize=(10, 6))
contour = plt.contour(X, Y, Z, levels=50, cmap='viridis')
plt.clabel(contour, inline=True, fontsize=8)

# Plot the gradient descent path
points = np.array(points)  # Convert list of points to a numpy array
plt.plot(points[:, 0], points[:, 1], marker='o', color='red', label='Gradient Descent Path')

# Mark the minimum point
plt.plot(point[0], point[1], marker='x', color='blue', markersize=10, label='Minimum Point (0, 0)')

# Add labels and legend
plt.title('Gradient Descent on $f(x, y) = x^2 + y^2$')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid()
plt.colorbar(label='Function Value')
plt.xlim(-6, 6)
plt.ylim(-6, 6)
plt.axhline(0, color='black',linewidth=0.5, ls='--')
plt.axvline(0, color='black',linewidth=0.5, ls='--')

plt.show()
# Out:
# Converged in 64 iterations.
# Minimum found at: [3.13855087e-06 3.13855087e-06]
# Minimum value of f at this point: 1.97010030981973E-11

# %% [markdown]
# ## Optimization of a Quadratic Function
# We seek to minimize the function f(x)
# 1. Calculate the derivative of the function.
# 2. Find the critical points.
# 3. Determine whether the critical point found is a minimum or a maximum.
# 4. Verify your results using the second derivative test.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp

# Step 1: Define the variable
x = sp.symbols('x')

# Step 2: Define the function
f = x**2 + 4*x + 4

# Step 3: Calculate the first derivative
f_prime = sp.diff(f, x)

# Step 4: Find the critical points by setting the first derivative to zero
critical_points = sp.solve(f_prime, x)

# Step 5: Calculate the second derivative
f_double_prime = sp.diff(f_prime, x)

# Step 6: Evaluate the second derivative at the critical point
second_derivative_value = f_double_prime.subs(x, critical_points[0])

# Step 7: Determine the nature of the critical point
if second_derivative_value > 0:
    nature = "local minimum"
elif second_derivative_value < 0:
    nature = "local maximum"
else:
    nature = "inconclusive"

# Display the results
print("The critical points are:", critical_points)
print("The second derivative at the critical point is:", second_derivative_value)
print("The critical point is a:", nature)

# Step 8: Plotting the function
# Create a range of x values
x_vals = np.linspace(-5, 2, 100)
# Calculate the corresponding y values for the function
f_vals = [f.subs(x, val) for val in x_vals]

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(x_vals, f_vals, label='f(x) = x^2 + 4x + 4', color='blue')
plt.scatter(float(critical_points[0]), float(f.subs(x, critical_points[0])), color='red', label='Critical Point (-2, 0)')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.title('Plot of the Function with Critical Point')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid()
plt.show()
# Out:
# The critical points are: [-2]
# The second derivative at the critical point is: 2
# The critical point is a: local minimum

# %% [markdown]
# ## Minimization of a Cubic Function
#
# 1. Determine the gradient of the function.
# 2. Identify the critical points (the points where the gradient is zero).
# 3. Calculate the Hessian matrix.
# 4. Determine the nature of the critical points:
# 5. Minimum
# 6. Maximum
# 7. Saddle point

# %%
import numpy as np
import sympy as sp

# Define the variables
x, y = sp.symbols('x y')

# Define the function
f = x**3 - 6*x**2 + 9*x + y**3 - 6*y

# Step 1: Gradient
grad_f = [sp.diff(f, var) for var in (x, y)]

# Step 2: Solve for critical points (where gradient is zero)
critical_points = sp.solve(grad_f, (x, y))

# Step 3: Hessian matrix
Hessian = sp.hessian(f, (x, y))

# Step 4: Determine the nature of the critical points
nature_of_points = []
for point in critical_points:
    H_val = Hessian.subs({x: point[0], y: point[1]})
    det_H = H_val.det()
    
    if det_H > 0:
        if H_val[0, 0] > 0:
            nature_of_points.append((point, 'Local Minimum'))
        else:
            nature_of_points.append((point, 'Local Maximum'))
    elif det_H < 0:
        nature_of_points.append((point, 'Saddle Point'))
    else:
        nature_of_points.append((point, 'Inconclusive'))

# Display results
grad_f, critical_points, Hessian, nature_of_points
# Out:
# ([3*x**2 - 12*x + 9, 3*y**2 - 6],
#  [(1, -sqrt(2)), (1, sqrt(2)), (3, -sqrt(2)), (3, sqrt(2))],
#  Matrix([
#  [6*x - 12,   0],
#  [       0, 6*y]]),
#  [((1, -sqrt(2)), 'Local Maximum'),
#   ((1, sqrt(2)), 'Saddle Point'),
#   ((3, -sqrt(2)), 'Saddle Point'),
#   ((3, sqrt(2)), 'Local Minimum')])

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import sympy as sp

# Définir la fonction
def f(x, y):
    return x**3 - 6*x**2 + 9*x + y**3 - 6*y

# Définir les valeurs pour x et y
x_vals = np.linspace(-1, 6, 400)
y_vals = np.linspace(-3, 3, 400)
X, Y = np.meshgrid(x_vals, y_vals)

# Calculer les valeurs de la fonction
Z = f(X, Y)

# Créer le graphique 3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Tracer la surface
ax.plot_surface(X, Y, Z, cmap='viridis', alpha=0.7)

# Calculer les points critiques
x, y = sp.symbols('x y')
f_sym = x**3 - 6*x**2 + 9*x + y**3 - 6*y
grad_f = [sp.diff(f_sym, var) for var in (x, y)]
critical_points = sp.solve(grad_f, (x, y))

# Tracer les points critiques
for point in critical_points:
    ax.scatter(point[0], point[1], f(point[0], point[1]), color='red', s=100)  # Rouge pour les points critiques
    ax.text(point[0], point[1], f(point[0], point[1]), f'({point[0]:.2f}, {point[1]:.2f})', fontsize=12)

# Étiquettes et titre
ax.set_title('3D Plot of f(x, y) = x³ - 6x² + 9x + y³ - 6y')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x, y)')

# Afficher le graphique
plt.show()

# %% [markdown]
# **Univariate Function Minimization**
#
# We aim to find the minimum of the function
#
# f(x) = x^4 - 10x^2 + 9
#
# 1. Visualize the function and the optimal point found.
# 2. Implement a function that calculates the gradient.
# 3. Implement the gradient descent algorithm.
# 4. Choose the initial point x0 = 10.
# 5. Then apply the descent.
# 6. Compare the performance with minimize_scalar from scipy.optimize.

# %% [markdown]
# **Visualize the function and the optimal point found**

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return x**4 - 10*x**2 + 9

x = np.linspace(-5, 5, 400)
y = f(x)

plt.figure(figsize=(8, 6))
plt.plot(x, y)
plt.title('Function f(x) = x^4 - 10x^2 + 9')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.show()

# %% [markdown]
# **The gradient descent algorithm VS minimize_scalar from scipy.optimize**

# %%
import numpy as np
from scipy.optimize import minimize_scalar

# Define the function f(x)
def f(x):
    return x**4 - 10*x**2 + 9

# Define the gradient f'(x)
def gradient(x):
    return 4*x**3 - 20*x

# Implement the gradient descent algorithm
def gradient_descent(starting_point, learning_rate=0.01, tolerance=1e-6, max_iterations=10000):
    x = starting_point
    for _ in range(max_iterations):
        grad = gradient(x)
        x_new = x - learning_rate * grad
        
        # Check for convergence
        if abs(x_new - x) < tolerance:
            break
        x = x_new
        
    return x

# Apply gradient descent starting from a smaller x0
x0 = 2  # Changed starting point to 2
learning_rate = 0.01  # Reduced learning rate
minimum_gd = gradient_descent(x0, learning_rate)

# Use minimize_scalar from scipy.optimize for comparison
result_scipy = minimize_scalar(f)

minimum_gd, result_scipy.x, f(minimum_gd), f(result_scipy.x)
# Out:
# (2.2360655182650153, 2.2360679775742365, -15.99999999987904, -16.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize_scalar

# Define the function f(x)
def f(x):
    return x**4 - 10*x**2 + 9

# Define the gradient f'(x)
def gradient(x):
    return 4*x**3 - 20*x

# Implement the gradient descent algorithm
def gradient_descent(starting_point, learning_rate=0.01, tolerance=1e-6, max_iterations=10000):
    x = starting_point
    for _ in range(max_iterations):
        grad = gradient(x)
        x_new = x - learning_rate * grad
        
        # Check for convergence
        if abs(x_new - x) < tolerance:
            break
        x = x_new
        
    return x

# Apply gradient descent starting from a smaller x0
x0 = 2  # Changed starting point to 2
learning_rate = 0.01  # Reduced learning rate
minimum_gd = gradient_descent(x0, learning_rate)

# Use minimize_scalar from scipy.optimize for comparison
result_scipy = minimize_scalar(f)

# Create the x values for plotting
x_values = np.linspace(-3, 3, 400)
y_values = f(x_values)

# Plot the function
plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label='$f(x) = x^4 - 10x^2 + 9$', color='blue')

# Plot the minimum found by gradient descent
plt.plot(minimum_gd, f(minimum_gd), 'ro', markersize=10, label='Gradient Descent Minimum')
plt.text(minimum_gd, f(minimum_gd) + 2, f'GD: ({minimum_gd:.2f}, {f(minimum_gd):.2f})', fontsize=9, ha='center', color='red')

# Plot the minimum found by minimize_scalar
plt.plot(result_scipy.x, f(result_scipy.x), 'go', markersize=10, label='Minimize Scalar Minimum')
plt.text(result_scipy.x, f(result_scipy.x) - 2, f'MS: ({result_scipy.x:.2f}, {f(result_scipy.x):.2f})', fontsize=9, ha='center', color='green')

# Set dynamic y-axis limits based on the function values
plt.ylim(min(y_values) - 5, max(y_values) + 5)

# Add labels and title
plt.title('Function Minimization')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.legend()
plt.xlim(-3, 3)    # Limit x-axis for better visualization
plt.show()

# %% [markdown]
# ## Fitting an exponential curve
#
# We have a set of data (x, y) representing the evolution of a population over time. We want to fit an exponential model of the form to this data.
# Use the minimize function from scipy.optimize to find the parameters that minimize the mean squared error between the values predicted by the model and the observed values.
#
# **y = a exp(bx)**

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)
n_points = 1000

# Define the constants
a = 2
b = 0.5

# Generate time values
t = np.random.rand(n_points) * 10

# Increase the noise standard deviation to 20
noise_std = 20

# Calculate the population values with added Gaussian noise
population = a * np.exp(b * t) + np.random.randn(n_points) * noise_std

# Scale and shift the population values to fit within the range [0, 1000]
population = (population - np.min(population)) / (np.max(population) - np.min(population)) * 900 + 100

# Plot the data
plt.figure(figsize=(8, 6))
plt.scatter(t, population, label='Noisy points')
plt.xlabel('Time')
plt.ylabel('Population')
plt.title('Evolution of a population over time with added noise')
plt.legend()
plt.show()

# %%
import pandas as pd

# Create the DataFrame
df = pd.DataFrame({'time': t, 'population': population})

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   time        1000 non-null   float64
#  1   population  1000 non-null   float64
# dtypes: float64(2)
# memory usage: 15.8 KB

# %% [markdown]
# ## Linear Regression

# %%
import matplotlib.pyplot as plt
import numpy as np

def linear_regression_analytical(x, y):
    N = len(x)
    m = (N * np.sum(x * y) - np.sum(x) * np.sum(y)) / (N * np.sum(x**2) - np.sum(x)**2)
    b = (np.sum(y) - m * np.sum(x)) / N
    return m, b


# Calculate the slope and y-intercept of the best fit line
x = df['time']
y = df['population']
m_analytical, b_analytical = linear_regression_analytical(x, y)

# Create a scatter plot of the data
plt.scatter(x, y, color='blue')

# Create a line using the slope and y-intercept
plt.plot(x, m_analytical*x + b_analytical, color='red')

# Add labels and title
plt.xlabel('Time')
plt.ylabel('Population')
plt.title('Linear Regression: Time vs Population')

# Show the plot
plt.show()

# %% [markdown]
# ## Mean Squared Error (MSE)

# %%
import numpy as np
import matplotlib.pyplot as plt

def mean_squared_error(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

def linear_regression_gradient_descent(x, y, learning_rate=0.01, n_iterations=10):
    m, b = 0, 0  # Initialization
    N = len(y)

    # History for visualization
    mse_history = []
    m_history, b_history = [], []

    for _ in range(n_iterations):
        y_pred = m * x + b
        dm = (-2/N) * np.sum(x * (y - y_pred))  # Derivative with respect to m
        db = (-2/N) * np.sum(y - y_pred)        # Derivative with respect to b
        m -= learning_rate * dm
        b -= learning_rate * db

        # Record history for visualization
        mse_history.append(mean_squared_error(y, y_pred))
        m_history.append(m)
        b_history.append(b)

    return m, b, mse_history, m_history, b_history

# Define the input and output data
x = df['time']
y = df['population']

# Calculate the slope, y-intercept, and MSE history using gradient descent
m_gd, b_gd, mse_history, m_history, b_history = linear_regression_gradient_descent(x, y)

# Create a plot of the MSE history
plt.plot(range(len(mse_history)), mse_history)

# Add labels and title
plt.xlabel('Iteration')
plt.ylabel('Mean Squared Error')
plt.title('Convergence of Gradient Descent')

# Show the plot
plt.show()

# %%
# Plot the data points, the analytical regression line, and the gradient descent regression line
plt.scatter(x, y, label='Data', color='blue', s=1)
plt.plot(x, m_analytical * x + b_analytical, color='red', label='Analytical Regression')
plt.plot(x, m_gd * x + b_gd, color='green', label='Gradient Descent')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.title('Line Fitting')
plt.show()

# Print the slope and y-intercept for both the analytical regression and the gradient descent
print(f"Analytical Regression: m = {m_analytical}, b = {b_analytical}")
print(f"Gradient Descent: m = {m_gd}, b = {b_gd}")
# Out:
# Analytical Regression: m = 53.36412414980744, b = 98.78689718410641
# Gradient Descent: m = 66.1213601250204, b = 14.434565220177776

# %% [markdown]
# # Non-Differentiable Optimization
#
# - **L1 Regularization**: Suppose we have a dataset of customer purchase data, where each data point represents a customer and indicates their purchases over a period of time. We can use a linear regression model to predict future purchases based on various features such as demographics, browsing history, and purchase history.
# - **K-Means Clustering**: Suppose we have a dataset of customer data, where each data point represents a customer and includes various features such as age, income, and usage patterns. We can use k-means clustering to group the customers into different segments based on their similarities.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the functions
def f1(x):
    return x**2

def f2(x):
    return np.abs(x)

def f3(x):
    return 2*x + 1

def f4(x):
    return np.exp(x)

# Define the range of x values to plot
x = np.linspace(-5, 5, 400)

# Create a figure and axis objects for each subplot
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Plot the functions in each subplot
axs[0, 0].plot(x, f1(x))
axs[0, 0].set_title('f(x) = x^2')

axs[0, 1].plot(x, f2(x))
axs[0, 1].set_title('f(x) = |x|')

axs[1, 0].plot(x, f3(x))
axs[1, 0].set_title('f(x) = 2x + 1')

axs[1, 1].plot(x, f4(x))
axs[1, 1].set_title('f(x) = e^x')

# Adjust the spacing between subplots
fig.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# The function that is not differentiable is b) |x|, which is the absolute value function. This function is not differentiable at x=0 because the derivative of the function changes abruptly from negative to positive as x crosses zero.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the convex function
def f(x):
    return x**2

# Define the subdifferential of the convex function
def subdiff(x):
    return [2*x]

# Define the range of x values to plot
x = np.linspace(-5, 5, 400)

# Create a figure and axis object
fig, ax = plt.subplots()

# Plot the function
ax.plot(x, f(x), label='f(x) = x^2')

# Plot the subdifferential at a few points
for x0 in [-3, 0, 2]:
    y0 = f(x0)
    m = subdiff(x0)[0]
    x1 = np.linspace(x0-1, x0+1, 100)
    y1 = m*(x1-x0) + y0
    ax.plot(x1, y1, '--', label=f'Subdiff at x={x0}')

# Add a legend
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# The subgradient of a function at a point is a set of vectors, rather than a single vector. This is because the subgradient is a generalization of the derivative, and the derivative of a function at a point is a single vector that represents the slope of the tangent line to the function at that point.

# %%
import numpy as np
from scipy.optimize import minimize_scalar

# Define the convex function
def f(x):
    return x**2

# Use scipy's minimize_scalar function to find the minimum
result = minimize_scalar(f)

# Print the minimum value and the corresponding x value
print(f"The minimum value of the function is {result.fun} at x = {result.x}")
# Out:
# The minimum value of the function is 0.0 at x = 0.0

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the functions
def f1(x):
    return np.abs(x)

def f2(x):
    return np.heaviside(x, 1)

def f3(x):
    return np.sign(x)

# Define the range of x values to plot
x = np.linspace(-5, 5, 400)

# Create a figure and axis objects for each subplot
fig, axs = plt.subplots(3, 1, figsize=(8, 12))

# Plot the functions in each subplot
axs[0].plot(x, f1(x))
axs[0].set_title('Absolute value function')

axs[1].plot(x, f2(x))
axs[1].set_title('Heaviside step function')

axs[2].plot(x, f3(x))
axs[2].set_title('Signum function')

# Add labels to the x-axis of the last subplot
axs[2].set_xlabel('x')

# Adjust the spacing between subplots
fig.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# **Non-Differentiable fonction**
#
# f(x) = |x-2|+|x+1|

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
def f(x):
    return np.abs(x-2) + np.abs(x+1)

# Define the range of x values to plot
x = np.linspace(-5, 5, 400)

# Create a figure and axis object
fig, ax = plt.subplots()

# Plot the function
ax.plot(x, f(x))

# Add labels and title
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
ax.set_title('f(x) = |x-2| + |x+1|')

# Show the plot
plt.show()

# %% [markdown]
# **The subgradient method**
#
# The subgradient method is a generalization of the gradient descent method that can be used to minimize non-differentiable functions.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
def f(x):
    return np.abs(x-2) + np.abs(x+1)

# Define the subgradient function
def subgradient(x):
    if x < -1:
        return -1
    elif -1 <= x < 2:
        return 0
    else:
        return 1

# Set the initial value of x
x = 0

# Set the learning rate
alpha = 0.1

# Set the number of iterations
num_iterations = 100

# Create a list to store the values of x at each iteration
x_values = [x]

# Use the subgradient method to minimize the function
for i in range(num_iterations):
    # Calculate the subgradient at the current point
    g = subgradient(x)

    # Update the value of x
    x = x - alpha * g

    # Add the new value of x to the list
    x_values.append(x)

# Print the final value of x
print("The minimum value of f(x) is achieved at x =", x)

# Define the range of x values to plot
x = np.linspace(-5, 5, 400)

# Create a figure and axis object
fig, ax = plt.subplots()

# Plot the function
ax.plot(x, f(x))

# Plot the values of x at each iteration
ax.plot(x_values, f(np.array(x_values)), 'ro-')

# Add labels and title
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
ax.set_title('f(x) = |x-2| + |x+1|')

# Show the plot
plt.show()
# Out:
# The minimum value of f(x) is achieved at x = 0.0

# %% [markdown]
# The subgradient method is guaranteed to converge to a minimum of the function f(x) if the following **conditions** are satisfied:
#
# 1. The function f(x) is convex. A function is convex if for any two points x and y in the domain of the function, the line segment between the points lies above the graph of the function.
# 2. The learning rate alpha is chosen appropriately. If the learning rate is too large, the method may not converge, and if it is too small, the method may converge slowly.
# 3. The initial value of x is chosen appropriately. If the initial value of x is too far from the minimum of the function, the method may take a long time to converge.

# %% [markdown]
# **Non-Differentiable fonction**
#
# - f(x) = |x-2|
# - x_0 = 0
# - iter = 10

# %%
import numpy as np

# Define the function
def f(x):
    return np.abs(x-2)

# Define the subgradient function
def subgradient(x):
    if x < 2:
        return -1
    elif x > 2:
        return 1
    else:
        return 0

# Set the initial value of x
x = 0

# Set the learning rate
alpha = 0.1

# Set the number of iterations
num_iterations = 10

# Use the subgradient method to minimize the function
for i in range(num_iterations):
    # Calculate the subgradient at the current point
    g = subgradient(x)

    # Update the value of x
    x = x - alpha * g

    # Print the current value of x
    print("Iteration", i+1, ": x =", x)

# Print the final value of x
print("The minimum value of f(x) is achieved at x =", x)
# Out:
# Iteration 1 : x = 0.1
# Iteration 2 : x = 0.2
# Iteration 3 : x = 0.30000000000000004
# Iteration 4 : x = 0.4
# Iteration 5 : x = 0.5
# Iteration 6 : x = 0.6
# Iteration 7 : x = 0.7
# Iteration 8 : x = 0.7999999999999999
# Iteration 9 : x = 0.8999999999999999
# Iteration 10 : x = 0.9999999999999999
# The minimum value of f(x) is achieved at x = 0.9999999999999999

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
def f(x):
    return np.abs(x-2)

# Define the subgradient function
def subgradient(x):
    if x < 2:
        return -1
    elif x > 2:
        return 1
    else:
        return 0

# Set the initial value of x
x = 0

# Set the learning rate
alpha = 0.5

# Set the number of iterations
num_iterations = 5

# Create a list to store the values of x at each iteration
x_values = [x]

# Use the subgradient method to minimize the function
for i in range(num_iterations):
    # Calculate the subgradient at the current point
    g = subgradient(x)

    # Update the value of x
    x = x - alpha * g

    # Add the new value of x to the list
    x_values.append(x)

    # Print the current value of x and the subgradient
    print("Iteration", i+1, ": x =", x, ", subgradient =", g)

# Print the final value of x
print("The minimum value of f(x) is achieved at x =", x)

# Define the range of x values to plot
x = np.linspace(-5, 5, 400)

# Create a figure and axis object
fig, ax = plt.subplots()

# Plot the function
ax.plot(x, f(x))

# Plot the values of x at each iteration
ax.plot(x_values, f(np.array(x_values)), 'ro-')

# Add labels and title
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
ax.set_title('f(x) = |x-2|')

# Show the plot
plt.show()
# Out:
# Iteration 1 : x = 0.5 , subgradient = -1
# Iteration 2 : x = 1.0 , subgradient = -1
# Iteration 3 : x = 1.5 , subgradient = -1
# Iteration 4 : x = 2.0 , subgradient = -1
# Iteration 5 : x = 2.0 , subgradient = 0
# The minimum value of f(x) is achieved at x = 2.0

# %% [markdown]
# **Non-Differentiable Fonction**
#
# f(x)=|x+y|+2|x-y|

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the function
def f(x, y):
    return np.abs(x + y) + 2 * np.abs(x - y)

# Create a grid of x and y values
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)
X, Y = np.meshgrid(x, y)

# Calculate the function values for each point in the grid
Z = f(X, Y)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')

# Set labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('f(X, Y)')

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Definition of the function f(x, y)
def f(x, y):
    return np.abs(x + y) + 2 * np.abs(x - y)

# Calculation of the subgradient of f(x, y)
def subgradient_f(x, y):
    subgrad_x = np.sign(x + y) + 2 * np.sign(x - y)
    subgrad_y = np.sign(x + y) - 2 * np.sign(x - y)
    return np.array([subgrad_x, subgrad_y])

# Subgradient algorithm with constant step size
def subgradient_descent_constant(alpha, num_iterations, x0, y0):
    x, y = x0, y0
    path = [(x, y)]
    for i in range(num_iterations):
        grad = subgradient_f(x, y)
        x -= alpha * grad[0]
        y -= alpha * grad[1]
        path.append((x, y))
    return np.array(path)

# Subgradient algorithm with decreasing step size 1/k
def subgradient_descent_decreasing(num_iterations, x0, y0):
    x, y = x0, y0
    path = [(x, y)]
    for i in range(1, num_iterations + 1):
        grad = subgradient_f(x, y)
        alpha = 1.0 / i
        x -= alpha * grad[0]
        y -= alpha * grad[1]
        path.append((x, y))
    return np.array(path)

# Initialization parameters
x0, y0 = 2, 2
num_iterations = 100
alpha = 0.1

# Applying the algorithms
path_constant = subgradient_descent_constant(alpha, num_iterations, x0, y0)
path_decreasing = subgradient_descent_decreasing(num_iterations, x0, y0)

# Creating the grid to visualize f(x, y)
x_vals = np.linspace(-5, 5, 400)  # Wider grid to capture more points
y_vals = np.linspace(-5, 5, 400)
X, Y = np.meshgrid(x_vals, y_vals)
Z = f(X, Y)

# Displaying the results of the optimized paths
print("Path (constant step size):\n", path_constant)
print("Path (decreasing step size):\n", path_decreasing)

# 3D visualization of the function
fig = plt.figure(figsize=(12, 6))

# 3D Visualization
ax = fig.add_subplot(121, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis', alpha=0.8)
ax.set_title('Surface of f(x, y)')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x, y)')

# Visualization of the optimization paths
ax2 = fig.add_subplot(122)
contour = ax2.contour(X, Y, Z, levels=50, cmap='viridis')

# Plotting the paths
ax2.plot(path_constant[:, 0], path_constant[:, 1], label="Constant step size", color='blue', marker='o')
ax2.plot(path_decreasing[:, 0], path_decreasing[:, 1], label="Decreasing step size", color='red', marker='x')
ax2.scatter(x0, y0, color='black', label='Starting point', zorder=5)
ax2.set_title("Path of the Subgradient Algorithm")
ax2.set_xlabel('x')
ax2.set_ylabel('y')

# Adjusting axis limits to include the paths
ax2.set_xlim([-5, 5])
ax2.set_ylim([-5, 5])

# Adding a legend
ax2.legend()

plt.show()
# Out:
# Path (constant step size):
#  [[ 2.00000000e+00  2.00000000e+00]
#  [ 1.90000000e+00  1.90000000e+00]
#  [ 1.80000000e+00  1.80000000e+00]
#  [ 1.70000000e+00  1.70000000e+00]
#  [ 1.60000000e+00  1.60000000e+00]
#  [ 1.50000000e+00  1.50000000e+00]
#  [ 1.40000000e+00  1.40000000e+00]
#  [ 1.30000000e+00  1.30000000e+00]
#  [ 1.20000000e+00  1.20000000e+00]
#  [ 1.10000000e+00  1.10000000e+00]
#  [ 1.00000000e+00  1.00000000e+00]
#  [ 9.00000000e-01  9.00000000e-01]
#  [ 8.00000000e-01  8.00000000e-01]
#  [ 7.00000000e-01  7.00000000e-01]
#  [ 6.00000000e-01  6.00000000e-01]
#  [ 5.00000000e-01  5.00000000e-01]
#  [ 4.00000000e-01  4.00000000e-01]
#  [ 3.00000000e-01  3.00000000e-01]
#  [ 2.00000000e-01  2.00000000e-01]
#  [ 1.00000000e-01  1.00000000e-01]
#  [-6.38378239e-16 -6.38378239e-16]
#  [ 1.00000000e-01  1.00000000e-01]
#  [-6.38378239e-16 -6.38378239e-16]
#  [ 1.00000000e-01  1.00000000e-01]
#  [-6.38378239e-16 -6.38378239e-16]
#  [ 1.00000000e-01  1.00000000e-01]
# ...
